# %%
import pandas as pd

prompts_dict = {
    "Author Identity Constraints": [
        "Assume you are Shakespeare. Write a story.",
        "Assume you are an award-winning literary writer. Write a story.",
        "Assume you are a high school student. Write a story.",
        "Assume you are a non-native speaker. Write a story.",
        "Assume you have dyslexia. Write a story.",
        "Assume you have a writing disability. Write a story.",
        "Assume you are a psychologist. Write a story.",
        "Assume you are an ancient philosopher. Write a story.",
        "Assume you are a retired detective. Write a story.",
        "Assume you are an astronaut. Write a story.",
        "Assume you are a street artist. Write a story.",
        "Assume you are a single parent. Write a story about hope.",
        "Assume you are blind. Write a story relying on sound and touch.",
        "Assume you are an adventurer. Write a story about a faraway city.",
        "Assume you are a superhero on a day off. Write a story.",
    ],
    "Socio-Historical Background": [
        "Assume you live in 18th century London. Write a story.",
        "Assume you live in Renaissance Florence. Write a story.",
        "Assume you live in 1920s New York. Write a story.",
        "Assume you are a civilian during World War II. Write a story.",
        "Assume you are an artisan in ancient Egypt. Write a story.",
        "Assume you are a scholar-official in the Qing dynasty. Write a story.",
        "Assume you are a citizen of a futuristic city. Write a story.",
        "Assume you live in medieval Japan. Write a story.",
        "Assume you are a gladiator in ancient Rome. Write a story.",
        "Assume you live during the Industrial Revolution in Britain. Write a story.",
        "Assume you are a 19th century female writer. Write a story.",
        "Assume you are a scientist in the former Soviet Union. Write a story.",
        "Assume you are a colonial-era explorer. Write a story.",
        "Assume you live in the Aztec empire. Write a story.",
        "Assume you are a child in a future space colony. Write a story.",
    ],
   "Character Personality": [
       "Assume you are a timid and shy person. Write a story.",
       "Assume you are extremely confident. Write a story.",
       "Assume you are a perfectionist. Write a story.",
       "Assume you are cheerful and optimistic. Write a story.",
       "Assume you are introverted. Write a story.",
       "Assume you are extroverted. Write a story.",
       "Assume you are eccentric. Write a story.",
       "Assume you are calm and rational. Write a story.",
       "Assume you are impulsive and easily angered. Write a story.",
       "Assume you are kind and gentle. Write a story.",
       "Assume you are mysterious. Write a story.",
       "Assume you are brave and fearless. Write a story.",
       "Assume you are pessimistic. Write a story.",
       "Assume you are extremely curious. Write a story.",
       "Assume you are indifferent. Write a story.",
   ],
    "Genre": [
        "Assume you are writing science fiction. Write a story.",
        "Assume you are writing a detective novel. Write a story.",
        "Assume you are writing a horror story. Write a story.",
        "Assume you are writing a romance. Write a story.",
        "Assume you are writing a humorous story. Write a story.",
        "Assume you are writing historical fiction. Write a story.",
        "Assume you are writing a fairy tale. Write a story.",
        "Assume you are writing a poetic short piece. Write a story.",
        "Assume you are writing a fable. Write a story.",
        "Assume you are writing a fantasy novel. Write a story.",
        "Assume you are writing realistic fiction. Write a story.",
        "Assume you are writing satire. Write a story.",
        "Assume you are writing an adventure story. Write a story.",
        "Assume you are writing a psychological thriller. Write a story.",
        "Assume you are writing a popular science story. Write a story.",
   ],
    "Emotional State": [
        "Assume you are extremely angry. Write a story.",
        "Assume you are extremely sad. Write a story.",
        "Assume you are happy. Write a story.",
        "Assume you are anxious and nervous. Write a story.",
        "Assume you are confused. Write a story.",
        "Assume you are full of hope. Write a story.",
        "Assume you are jealous. Write a story.",
        "Assume you are proud. Write a story.",
        "Assume you are ashamed. Write a story.",
        "Assume you are surprised. Write a story.",
        "Assume you are lonely. Write a story.",
        "Assume you are curious. Write a story.",
        "Assume you feel helpless. Write a story.",
        "Assume you feel calm. Write a story.",
        "Assume your emotions are complex and hard to describe. Write a story.",
    ],
     "Moral Framing": [
        "Assume you are extremely honest. Write a story.",
        "Assume you are cunning and scheming. Write a story.",
        "Assume you seek fairness and justice. Write a story.",
        "Assume you value personal gain. Write a story.",
        "Assume you are compassionate. Write a story.",
        "Assume you are cold and ruthless. Write a story.",
        "Assume you strictly obey the law. Write a story.",
        "Assume you are moral. Write a story.",
        "Assume you value family. Write a story.",
        "Assume you value social responsibility. Write a story.",
        "Assume you pursue personal freedom. Write a story.",
        "Assume you follow religious rules. Write a story.",
        "Assume you face moral dilemmas. Write a story.",
        "Assume you act against your conscience. Write a story.",
        "Assume you strive to do good. Write a story.",
    ],
    "Communicative Intent": [
        "Assume you try to persuade others. Write a story.",
        "Assume you try to please others. Write a story.",
        "Assume you try to scare others. Write a story.",
        "Assume you try to inspire others. Write a story.",
        "Assume you try to gain trust. Write a story.",
        "Assume you try to express sadness. Write a story.",
        "Assume you try to express anger. Write a story.",
        "Assume you try to express humor. Write a story.",
        "Assume you try to share a secret. Write a story.",
        "Assume you try to educate others. Write a story.",
        "Assume you try to entertain others. Write a story.",
        "Assume you try to motivate others. Write a story.",
        "Assume you try to express love. Write a story.",
        "Assume you try to hide your true intent. Write a story.",
        "Assume you try to make others understand your feelings. Write a story.",
    ],
     "Memory Structure" : [
        "Assume you have excellent long-term memory. Write a story.",
        "Assume you easily forget things. Write a story.",
        "Assume you have vivid memory. Write a story.",
        "Assume you remember only fragments. Write a story.",
        "Assume you have super visual memory. Write a story.",
        "Assume you rely on oral memory. Write a story.",
        "Assume your memory is disorganized and fragmented. Write a story.",
        "Assume you can recall details accurately. Write a story.",
        "Assume you tend to forget past experiences. Write a story.",
        "Assume you often confuse memory with imagination. Write a story.",
        "Assume you like to write down experiences to remember. Write a story.",
        "Assume you use images to aid memory. Write a story.",
        "Assume you are good at remembering numbers and dates. Write a story.",
        "Assume your memory is unusually clear and coherent. Write a story.",
     ],
      "Perceptual Framing" : [
        "Assume you understand the world visually. Write a story.",
        "Assume you mainly rely on hearing. Write a story.",
        "Assume you perceive through touch. Write a story.",
        "Assume you are sensitive to smells and tastes. Write a story.",
        "Assume you perceive the environment through emotions. Write a story.",
        "Assume you like to observe others’ expressions. Write a story.",
        "Assume you understand others through body language. Write a story.",
        "Assume you understand the world through logic. Write a story.",
        "Assume you rely on intuition. Write a story.",
        "Assume you reconstruct the world through memory. Write a story.",
        "Assume you lean toward abstract thinking. Write a story.",
        "Assume you lean toward concrete sensory experience. Write a story.",
        "Assume your perception is sharp and easily stimulated. Write a story.",
        "Assume your perception is dull. Write a story.",
        "Assume you integrate multiple senses to understand the world. Write a story.",
    ],
      "Social Power Position" : [
        "Assume you are a national leader. Write a story.",
        "Assume you are an employee of a small company. Write a story.",
        "Assume you are a teacher. Write a story.",
        "Assume you are a student. Write a story.",
        "Assume you are wealthy. Write a story.",
        "Assume you are a commoner. Write a story.",
        "Assume you are middle management. Write a story.",
        "Assume you are a grassroots worker. Write a story.",
        "Assume you have academic authority. Write a story.",
        "Assume you are a social activist. Write a story.",
        "Assume you are at the social margin. Write a story.",
        "Assume you are a political novice. Write a story.",
        "Assume you are a highly influential public figure. Write a story.",
    ],
      "Degree of Self-Awareness" : [
        "Assume you are highly introspective. Write a story.",
        "Assume you rarely reflect on yourself. Write a story.",
        "Assume you are aware of your biases. Write a story.",
        "Assume you are unaware of your actions. Write a story.",
        "Assume you are good at analyzing your emotions. Write a story.",
        "Assume you rarely pay attention to your inner world. Write a story.",
        "Assume you are good at planning your thinking. Write a story.",
        "Assume you act instinctively. Write a story.",
        "Assume you can notice blind spots in your thinking. Write a story.",
        "Assume you fail to notice your mistakes. Write a story.",
        "Assume you always self-criticize. Write a story.",
        "Assume you rarely self-criticize. Write a story.",
        "Assume you are aware of your learning strategies. Write a story.",
        "Assume you ignore your learning process. Write a story.",
        "Assume you can effectively monitor your thinking and actions. Write a story.",
      ]
}


data = []
for theme, prompts in prompts_dict.items():
    for prompt in prompts:
        data.append({"Theme": theme, "Prompt": prompt})

df = pd.DataFrame(data)


df.to_csv("prompts.csv", index=False)
print("prompts.csv has been created with", len(df), "rows.")
# Out:
# prompts.csv has been created with 162 rows.
